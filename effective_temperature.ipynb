# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib widget
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import geopandas
import os
import georasters as gr
import glob

from geo_scripts.process_height import *

# %%
# ET = ((18 * MWT) - (10 * MCM))/(MWM - MCM + 8)
# MWT = Mean temperature of warmest month of year
# MCT = Mean Temperature of coldest month of year

# %%
effective_temperature = np.load("./data/effective_temperature_large.npy")
effective_mask = np.load("./data/effective_temperature_large_mask.npy")
effective_temperature = np.ma.array(effective_temperature, mask=effective_mask)

# %%
geot = (-180.00013888885002, 0.0083333333, 0.0, 83.99986041515001, 0.0, -0.0083333333)

# %%
raster = gr.GeoRaster(effective_temperature, geot)

# %%
x_ranges = list(gen_ranges(-180, 180, 1))
y_ranges = list(gen_ranges(90, -90, 1))
aggregated = aggregate_grid(raster, x_ranges, y_ranges)

# %%
plt.imshow(aggregated)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# terrestrial plant threshold
tpt = aggregated > 12.75

# %%
plt.imshow(tpt)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
temp01.shape
# Out:
# (20880, 43200)

# %%
x_ranges = list(gen_ranges(-180, 180, 1))
y_ranges = list(gen_ranges(90, -90, 1))

temps = []
