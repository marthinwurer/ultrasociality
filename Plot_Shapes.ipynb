# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib widget
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import geopandas
import os

# %%
df = geopandas.read_file(os.path.expanduser("~/Downloads/datasets/natural_earth/ne_50m_ocean/ne_50m_ocean.shp"))
df_river = geopandas.read_file(os.path.expanduser("~/Downloads/datasets/natural_earth/ne_50m_rivers_lake_centerlines_scale_rank/ne_50m_rivers_lake_centerlines_scale_rank.shp"))
df_lake = geopandas.read_file(os.path.expanduser("~/Downloads/datasets/natural_earth/ne_50m_lakes/ne_50m_lakes.shp"))
df_lake_historic = geopandas.read_file(os.path.expanduser("~/Downloads/datasets/natural_earth/ne_50m_lakes_historic/ne_50m_lakes_historic.shp"))
base_map = df.plot()
# df_river = df_river[:100]
river_plot = df_river.plot(ax=base_map)
lakes_h_plot = df_lake_historic.plot(ax=base_map)
lakes_plot = df_lake.plot(ax=base_map)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df_lake
# Out:
#    scalerank     featurecla       name name_alt  min_zoom wikidataid  \
# 0          3  Historic Lake   Aral Sea     None       5.0     Q35883
# 1          5  Historic Lake  Lake Chad     None       6.0    Q125309
#
#                 label     name_ar   name_bn    name_de  ...           name_pl  \
# 0   Historic Aral Sea    بحر آرال      None    Aralsee  ...  Jezioro Aralskie
# 1  Historic Lake Chad  بحيرة تشاد  চাদ হ্রদ  Tschadsee  ...              Czad
#
#        name_pt         name_ru    name_sv    name_tr    name_vi name_zh  \
# 0  Mar de Aral  Аральское море   Aralsjön  Aral Gölü  Biển Aral      鹹海
# 1   Lago Chade             Чад  Tchadsjön   Çad Gölü   Hồ Tchad     乍得湖
#
#   wdid_score       ne_id                                           geometry
# 0          5  1159110427  POLYGON ((60.21527 46.72382, 60.31408 46.73384...
# 1          5  1159110451  POLYGON ((15.29243 13.23020, 15.28137 13.12633...
#
# [2 rows x 31 columns]

# %%
df_river.properties
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-393fdbaba6da> in <module>
# ----> 1 df_river.properties
#
# ~/.pyenv/versions/3.7.3/envs/georasters/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'GeoDataFrame' object has no attribute 'properties'
